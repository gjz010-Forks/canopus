# %%
import canopus
import pytket.qasm
import qiskit

fname = './experiments/output/logical/sat_n11.qasm'

circ = pytket.qasm.circuit_from_qasm(fname)
qc = canopus.utils.tket_to_qiskit(circ)

# %%
from qiskit.transpiler import PassManager, passes

# %%
.count_ops()
# Out:
# OrderedDict([('u', 502), ('cx', 252)])

# %%
qc.count_ops()
# Out:
# OrderedDict([('u', 263), ('can', 210)])
