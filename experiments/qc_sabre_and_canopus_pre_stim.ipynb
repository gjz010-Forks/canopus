# %%
import sys
sys.path.append('..')

import canopus
from qiskit import QuantumCircuit

# %%
qc_sabre_cx = QuantumCircuit.from_qasm_file('qc_sabre_cx.qasm')
qc_sabre_stab = QuantumCircuit.from_qasm_file('qc_sabre_stab.qasm')
qc_canopus_cx = QuantumCircuit.from_qasm_file('qc_canopus_cx.qasm')
qc_canopus_stab = QuantumCircuit.from_qasm_file('qc_canopus_stab.qasm')

canopus.utils.print_circ_info(qc_sabre_cx, title='qc_sabre_cx')
canopus.utils.print_circ_info(qc_sabre_stab, title='qc_sabre_stab')
canopus.utils.print_circ_info(qc_canopus_cx, title='qc_canopus_cx')
canopus.utils.print_circ_info(qc_canopus_stab, title='qc_canopus_stab')
# Out:
# +----------------------------------------------------------+
# |                       qc_sabre_cx                        |
# +------------+-----------+--------------+-------+----------+
# | num_qubits | num_gates | num_2q_gates | depth | depth_2q |
# +------------+-----------+--------------+-------+----------+
# |     13     |    266    |      95      |   70  |    39    |
# +------------+-----------+--------------+-------+----------+
# +----------------------------------------------------------+
# |                      qc_sabre_stab                       |
# +------------+-----------+--------------+-------+----------+
# | num_qubits | num_gates | num_2q_gates | depth | depth_2q |
# +------------+-----------+--------------+-------+----------+
# |     13     |    361    |      70      |   88  |    28    |
# +------------+-----------+--------------+-------+----------+
# +----------------------------------------------------------+
# ...
